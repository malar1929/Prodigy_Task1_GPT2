# %%
# %%writefile README.md
# # Prodigy InfoTech Internship - Task 1
# ## Text Generation using GPT-2
#
# **Name:** [ACTUAL NAME PODU DA]  # 💡 CHANGE THIS!
# **College:** [COLLEGE NAME]
# **Internship ID:** [PRODIGY ID]
# **Date:** 02/01/2024
#
# ## 📌 Overview
# Used GPT-2 model to generate coherent text based on given prompts using Hugging Face Transformers.
#
# ## 🛠️ Technologies Used
# - Python 3.x
# - Hugging Face Transformers
# - Google Colab
# - Jupyter Notebook
#
# ## 📂 Files Generated
# 1. `prodigy_task1_GPT2.ipynb` - Main code notebook
# 2. `gpt2_output.csv` - Single prompt output
# 3. `multiple_prompts.csv` - Multiple prompts output
# 4. `improved_output.html` - Enhanced HTML output
# 5. `output.html` - Simple HTML output
# 6. `prodigy_task1_final.zip` - Compressed submission
#
# ## 🚀 How to Run
# 1. Open `prodigy_task1_GPT2.ipynb` in Google Colab
# 2. Run all cells sequentially
# 3. Check outputs in CSV/HTML files
#
# ## 📊 Results
# ### Single Prompt:
# **Prompt:** "Artificial Intelligence is"
# **Generated:** "Artificial Intelligence is a topic that could only be addressed by bringing the world's leading technology into reality..."
#
# ### Multiple Prompts: (See multiple_prompts.csv)
# - "The future of machine learning"
# - "In the world of deep learning"
# - "Natural Language Processing can"
#
# ## 🎯 Learning Outcomes
# - Learned to use Hugging Face Transformers library
# - Implemented text generation with GPT-2
# - Saved outputs in multiple formats (CSV, HTML)
# - Created professional documentation
# Out:
# Overwriting README.md

# %%
import pandas as pd
df_multiple_prompts = pd.read_csv('multiple_prompts.csv')
display(df_multiple_prompts)
# Out:
#                             Prompt  \
# 0       Artificial Intelligence is
# 1   The future of machine learning
# 2    In the world of deep learning
# 3  Natural Language Processing can
#
#                                       Generated Text
# 0  Artificial Intelligence is an amazing concept ...
# 1  The future of machine learning and machine lea...
# 2  In the world of deep learning, there may be an...
# 3  Natural Language Processing can be used to con...

# %%
# !pip install transformers --quiet
import csv
from transformers import AutoTokenizer, AutoModelForCausalLM
print("✅ Libraries imported successfully!")
try:
    print("🔄 Loading GPT-2 model and tokenizer...")
    tokenizer = AutoTokenizer.from_pretrained("gpt2")
    model = AutoModelForCausalLM.from_pretrained("gpt2")
    print("✅ Model loaded successfully!")
except Exception as e:
    print(f"❌ Error loading model: {e}")
prompt = "Artificial Intelligence is"
print(f"\n📝 Prompt: {prompt}")
inputs = tokenizer(prompt, return_tensors="pt")
outputs = model.generate(
    **inputs,
    max_new_tokens=100,
    do_sample=True,
    temperature=0.8,
    top_p=0.95,
    repetition_penalty=1.2,
    pad_token_id=tokenizer.eos_token_id
)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(f"\n🤖 Generated Text:\n{generated_text}")
# Out:
# ✅ Libraries imported successfully!
# 🔄 Loading GPT-2 model and tokenizer...
# ✅ Model loaded successfully!
#
# 📝 Prompt: Artificial Intelligence is
#
# 🤖 Generated Text:
# Artificial Intelligence is going to be our future.
# If you haven't already, I've written about the science of AI before: You can buy a copy for $1 off your first month using eBay's free shipping and savings code 'AVIC'. To learn more…

# %%
prompts = [
    "Artificial Intelligence is",
    "The future of machine learning",
    "In the world of deep learning",
    "Natural Language Processing can"
]

all_results = []
for p in prompts:
    print(f"\n{'='*50}")
    print(f"Prompt: {p}")
    inputs = tokenizer(p, return_tensors="pt")
    outputs = model.generate(**inputs, max_new_tokens=80, do_sample=True)
    text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(f"Generated: {text}")
    all_results.append([p, text])
with open("multiple_prompts.csv", "w", newline="", encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(["Prompt", "Generated Text"])
    writer.writerows(all_results)
print("\n✅ All results saved to 'multiple_prompts.csv'")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ==================================================
# Prompt: Artificial Intelligence is
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated: Artificial Intelligence is an amazing concept that makes us want more. As we look closer at our data, and discover things that we can use to solve real-world problems, we will find interesting possibilities that are so close to what we see in the machine intelligence world, that we must also consider what those possibilities mean to us, because it is worth their weight in gold if you consider not just the things we get from
#
# ==================================================
# Prompt: The future of machine learning
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated: The future of machine learning and machine learning research will depend almost entirely on computer algorithms and algorithms that will be able to tell if you're right.
#
# But in the meantime, companies should keep in mind that there's a good chance humans will soon be able to do something that we have little or no experience with at all. As with all interesting phenomena, a new frontier is just around the corner.
#
# This interview
#
# ==================================================
# Prompt: In the world of deep learning
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated: In the world of deep learning, there may be an obvious need for much more than just a neural framework to be used in applications. Deep neural networks are a great tool for a number of applications, and one might find that using them as a starting point for future research, including machine learning, is the best way to implement them.
#
# Many deep learning frameworks can provide an array of new features along the way. For example
#
# ==================================================
# Prompt: Natural Language Processing can
# Generated: Natural Language Processing can be used to convert a dictionary into a dictionary, and it works for any user program. You'll find all the words you've used to express yourself, plus many more you'll find later on. So what does all this do?
#
# The most important thing to note about the language processing library is that it takes a small amount of memory each time you start reading from it. To illustrate this
#
# ✅ All results saved to 'multiple_prompts.csv'

# %%
html_content = '''
<!DOCTYPE html>
<html>
<head>
    <title>GPT-2 Text Generation Results</title>
    <style>
        body { font-family: Arial, sans-serif; margin: 40px; background: #f5f5f5; }
        .container { max-width: 800px; margin: auto; background: white; padding: 30px; border-radius: 10px; box-shadow: 0 0 10px rgba(0,0,0,0.1); }
        h1 { color: #333; border-bottom: 3px solid #4CAF50; padding-bottom: 10px; }
        .prompt { background: #e8f5e9; padding: 15px; border-left: 5px solid #4CAF50; margin: 20px 0; }
        .output { background: #e3f2fd; padding: 15px; border-left: 5px solid #2196F3; }
        .footer { margin-top: 30px; color: #666; font-size: 0.9em; text-align: center; }
    </style>
</head>
<body>
    <div class="container">
        <h1>🎯 GPT-2 Text Generation Task</h1>
        <p><strong>Internship:</strong> Prodigy InfoTech</p>
        <p><strong>Task:</strong> Text Generation using GPT-2</p>

        <h2>📝 Original Prompt</h2>
        <div class="prompt">
            <strong>Prompt:</strong> ''' + prompt + '''
        </div>

        <h2>🤖 Generated Output</h2>
        <div class="output">
            ''' + generated_text.replace('\n', '<br>') + '''
        </div>

        <div class="footer">
            Generated using Hugging Face Transformers | GPT-2 Model
        </div>
    </div>
</body>
</html>
'''
with open("improved_output.html", "w", encoding="utf-8") as f:
    f.write(html_content)
print("✅ Improved HTML file created!")
# Out:
# ✅ Improved HTML file created!

# %%
# !zip -r prodigy_task1_final.zip \
    Prodigy_Task1_GPT2.ipynb \
    README.md \
    gpt2_output.csv \
    multiple_prompts.csv \
    improved_output.html \
    output.html
print("📦 Final zip created: 'prodigy_task1_final.zip'")
print("Contains all improved files!")
# Out:
# 	zip warning: name not matched: Prodigy_Task1_GPT2.ipynb
# 	zip warning: name not matched: gpt2_output.csv
# 	zip warning: name not matched: output.html
# updating: README.md (deflated 45%)
# updating: multiple_prompts.csv (deflated 52%)
# updating: improved_output.html (deflated 53%)
# 📦 Final zip created: 'prodigy_task1_final.zip'
# Contains all improved files!
